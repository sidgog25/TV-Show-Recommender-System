# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.porter import PorterStemmer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("imdb_tvshows.csv")

# %%
df.head()
# Out:
#                  Title                                              About  \
# 0       The Family Man  A working man from the National Investigation ...
# 1              Lucifer  Lucifer Morningstar has decided he's had enoug...
# 2  The Handmaid's Tale  Set in a dystopian future, a woman is forced t...
# 3              StartUp  A desperate banker, a Haitian-American gang lo...
# 4      Game of Thrones  Nine noble families fight for control over the...
#
#    EpisodeDuration(in Minutes)                    Genres  \
# 0                         42.0     Action, Comedy, Drama
# 1                         45.0     Crime, Drama, Fantasy
# 2                         42.0   Drama, Sci-Fi, Thriller
# 3                         60.0           Crime, Thriller
# 4                         44.0  Action, Adventure, Drama
#
#                                               Actors  Rating    Votes  \
# 0  Manoj Bajpayee, Samantha Akkineni, Priyamani, ...     8.8    57632
# 1  Tom Ellis, Lauren German, Lesley-Ann Brandt, K...     8.1   252826
# 2  Elisabeth Moss, Yvonne Strahovski, Joseph Fien...     8.4   187007
# 3  Adam Brody, Edi Gathegi, Otmara Marrero, Krist...     8.0    18165
# 4  Emilia Clarke, Peter Dinklage, Kit Harington, ...     9.3  1823966
#
#        Years
# 0     2019–
# 1     2016–
# 2     2017–
# 3  2016–2018
# 4  2011–2019

# %%
print(df.columns)
# Out:
# Index(['Title', 'About', 'EpisodeDuration(in Minutes)', 'Genres', 'Actors',
#        'Rating', 'Votes', 'Years'],
#       dtype='object')

# %%
#We only want to keep any featurs that we can use to build tags
#Keep Title, About, Genres, Actors
#Drop numerical feaures - so episode duration, rating, votes, and years
df_new = df.drop(columns = ['EpisodeDuration(in Minutes)', 'Votes', 'Years'])

# %%
df_new
# Out:
#                                         Title  \
# 0                              The Family Man
# 1                                     Lucifer
# 2                         The Handmaid's Tale
# 3                                     StartUp
# 4                             Game of Thrones
# ...                                       ...
# 2995                                    Panic
# 2996  Ryan Hansen Solves Crimes on Television
# 2997                                    Doubt
# 2998                Friends with Better Lives
# 2999                               Love Daily
#
#                                                   About  \
# 0     A working man from the National Investigation ...
# 1     Lucifer Morningstar has decided he's had enoug...
# 2     Set in a dystopian future, a woman is forced t...
# 3     A desperate banker, a Haitian-American gang lo...
# 4     Nine noble families fight for control over the...
# ...                                                 ...
# 2995  A successful defense lawyer at a boutique firm...
# 2996  A comedy centered around six 30-something frie...
# 2997  Romantic anthology web series revolving around...
# 2998                                                NaN
# 2999                                                NaN
#
#                         Genres  \
# 0        Action, Comedy, Drama
# 1        Crime, Drama, Fantasy
# 2      Drama, Sci-Fi, Thriller
# 3              Crime, Thriller
# 4     Action, Adventure, Drama
# ...                        ...
# 2995             Comedy, Drama
# 2996     Action, Comedy, Crime
# 2997                     Drama
# 2998                    Comedy
# 2999                   Romance
#
#                                                  Actors  Rating
# 0     Manoj Bajpayee, Samantha Akkineni, Priyamani, ...     8.8
# 1     Tom Ellis, Lauren German, Lesley-Ann Brandt, K...     8.1
# 2     Elisabeth Moss, Yvonne Strahovski, Joseph Fien...     8.4
# 3     Adam Brody, Edi Gathegi, Otmara Marrero, Krist...     8.0
# 4     Emilia Clarke, Peter Dinklage, Kit Harington, ...     9.3
# ...                                                 ...     ...
# 2995  Christopher Cox, Olivia DiNino, Benjamin Hsieh...     9.3
# 2996  Ryan Hansen, Aly Michalka, Samira Wiley, Noell...     7.2
# 2997  Katherine Heigl, Dulé Hill, Laverne Cox, Dream...     5.6
# 2998  James Van Der Beek, Majandra Delfino, Zoe List...     7.0
# 2999  Kelli Berglund, Joey Bragg, Jack Griffo, Leo H...     6.1
#
# [3000 rows x 5 columns]

# %%
#checking for empty cells per feature
df_new.isnull().sum()
# Out:
# Title      0
# About     14
# Genres     0
# Actors     6
# Rating     0
# dtype: int64

# %%
#Since the number of empty cells is so low I shall drop these rows
df_new.dropna(inplace = True)

# %%
#Checking for duplicate rows
df_new.duplicated().sum()
# Out:
# 0

# %%
df_new = df_new.reset_index().drop(columns = ['index'])

# %%
df_new
# Out:
#                                         Title  \
# 0                              The Family Man
# 1                                     Lucifer
# 2                         The Handmaid's Tale
# 3                                     StartUp
# 4                             Game of Thrones
# ...                                       ...
# 2975                  The Beautiful Life: TBL
# 2976                   Star Trek: New Voyages
# 2977                                    Panic
# 2978  Ryan Hansen Solves Crimes on Television
# 2979                                    Doubt
#
#                                                   About  \
# 0     A working man from the National Investigation ...
# 1     Lucifer Morningstar has decided he's had enoug...
# 2     Set in a dystopian future, a woman is forced t...
# 3     A desperate banker, a Haitian-American gang lo...
# 4     Nine noble families fight for control over the...
# ...                                                 ...
# 2975  Meet Sam, a lonely teenager struggling through...
# 2976  In a world where Hollywood actors can partner ...
# 2977  A successful defense lawyer at a boutique firm...
# 2978  A comedy centered around six 30-something frie...
# 2979  Romantic anthology web series revolving around...
#
#                          Genres  \
# 0         Action, Comedy, Drama
# 1         Crime, Drama, Fantasy
# 2       Drama, Sci-Fi, Thriller
# 3               Crime, Thriller
# 4      Action, Adventure, Drama
# ...                         ...
# 2975                      Drama
# 2976  Action, Adventure, Sci-Fi
# 2977              Comedy, Drama
# 2978      Action, Comedy, Crime
# 2979                      Drama
#
#                                                  Actors  Rating
# 0     Manoj Bajpayee, Samantha Akkineni, Priyamani, ...     8.8
# 1     Tom Ellis, Lauren German, Lesley-Ann Brandt, K...     8.1
# 2     Elisabeth Moss, Yvonne Strahovski, Joseph Fien...     8.4
# 3     Adam Brody, Edi Gathegi, Otmara Marrero, Krist...     8.0
# 4     Emilia Clarke, Peter Dinklage, Kit Harington, ...     9.3
# ...                                                 ...     ...
# 2975  Mischa Barton, Benjamin Hollingsworth, Sara Pa...     5.7
# 2976  Charles Root, John M. Kelley, James Cawley, Je...     6.7
# 2977  Christopher Cox, Olivia DiNino, Benjamin Hsieh...     9.3
# 2978  Ryan Hansen, Aly Michalka, Samira Wiley, Noell...     7.2
# 2979  Katherine Heigl, Dulé Hill, Laverne Cox, Dream...     5.6
#
# [2980 rows x 5 columns]

# %% [markdown]
# ## Creating tags

# %%
df_new['About'] = df_new['About'].apply(lambda x:x.split()).apply(lambda x: [i.replace(",", "") for i in x])
df_new['Genres'] = df_new['Genres'].apply(lambda x:x.split()).apply(lambda x: [i.replace(",", "") for i in x])
df_new['Actors'] = df_new['Actors'].apply(lambda x:x.split(",")).apply(lambda x: [i.replace(",", "") for i in x])

# %%
df_new
# Out:
#                                         Title  \
# 0                              The Family Man
# 1                                     Lucifer
# 2                         The Handmaid's Tale
# 3                                     StartUp
# 4                             Game of Thrones
# ...                                       ...
# 2975                  The Beautiful Life: TBL
# 2976                   Star Trek: New Voyages
# 2977                                    Panic
# 2978  Ryan Hansen Solves Crimes on Television
# 2979                                    Doubt
#
#                                                   About  \
# 0     [A, working, man, from, the, National, Investi...
# 1     [Lucifer, Morningstar, has, decided, he's, had...
# 2     [Set, in, a, dystopian, future, a, woman, is, ...
# 3     [A, desperate, banker, a, Haitian-American, ga...
# 4     [Nine, noble, families, fight, for, control, o...
# ...                                                 ...
# 2975  [Meet, Sam, a, lonely, teenager, struggling, t...
# 2976  [In, a, world, where, Hollywood, actors, can, ...
# 2977  [A, successful, defense, lawyer, at, a, boutiq...
# 2978  [A, comedy, centered, around, six, 30-somethin...
# 2979  [Romantic, anthology, web, series, revolving, ...
#
#                            Genres  \
# 0         [Action, Comedy, Drama]
# 1         [Crime, Drama, Fantasy]
# 2       [Drama, Sci-Fi, Thriller]
# 3               [Crime, Thriller]
# 4      [Action, Adventure, Drama]
# ...                           ...
# 2975                      [Drama]
# 2976  [Action, Adventure, Sci-Fi]
# 2977              [Comedy, Drama]
# 2978      [Action, Comedy, Crime]
# 2979                      [Drama]
#
#                                                  Actors
# 0     [Manoj Bajpayee,  Samantha Akkineni,  Priyaman...
# 1     [Tom Ellis,  Lauren German,  Lesley-Ann Brandt...
# 2     [Elisabeth Moss,  Yvonne Strahovski,  Joseph F...
# 3     [Adam Brody,  Edi Gathegi,  Otmara Marrero,  K...
# 4     [Emilia Clarke,  Peter Dinklage,  Kit Haringto...
# ...                                                 ...
# 2975  [Mischa Barton,  Benjamin Hollingsworth,  Sara...
# 2976  [Charles Root,  John M. Kelley,  James Cawley,...
# 2977  [Christopher Cox,  Olivia DiNino,  Benjamin Hs...
# 2978  [Ryan Hansen,  Aly Michalka,  Samira Wiley,  N...
# 2979  [Katherine Heigl,  Dulé Hill,  Laverne Cox,  D...
#
# [2980 rows x 4 columns]

# %%
df_new['About'] = df_new['About'].apply(lambda x:[i.replace(" ", "") for i in x])
df_new['Genres'] = df_new['Genres'].apply(lambda x:[i.replace(" ", "") for i in x])
df_new['Actors'] = df_new['Actors'].apply(lambda x:[i.replace(" ", "") for i in x])

# %%
df_new
# Out:
#                                         Title  \
# 0                              The Family Man
# 1                                     Lucifer
# 2                         The Handmaid's Tale
# 3                                     StartUp
# 4                             Game of Thrones
# ...                                       ...
# 2975                  The Beautiful Life: TBL
# 2976                   Star Trek: New Voyages
# 2977                                    Panic
# 2978  Ryan Hansen Solves Crimes on Television
# 2979                                    Doubt
#
#                                                   About  \
# 0     [A, working, man, from, the, National, Investi...
# 1     [Lucifer, Morningstar, has, decided, he's, had...
# 2     [Set, in, a, dystopian, future, a, woman, is, ...
# 3     [A, desperate, banker, a, Haitian-American, ga...
# 4     [Nine, noble, families, fight, for, control, o...
# ...                                                 ...
# 2975  [Meet, Sam, a, lonely, teenager, struggling, t...
# 2976  [In, a, world, where, Hollywood, actors, can, ...
# 2977  [A, successful, defense, lawyer, at, a, boutiq...
# 2978  [A, comedy, centered, around, six, 30-somethin...
# 2979  [Romantic, anthology, web, series, revolving, ...
#
#                            Genres  \
# 0         [Action, Comedy, Drama]
# 1         [Crime, Drama, Fantasy]
# 2       [Drama, Sci-Fi, Thriller]
# 3               [Crime, Thriller]
# 4      [Action, Adventure, Drama]
# ...                           ...
# 2975                      [Drama]
# 2976  [Action, Adventure, Sci-Fi]
# 2977              [Comedy, Drama]
# 2978      [Action, Comedy, Crime]
# 2979                      [Drama]
#
#                                                  Actors
# 0     [ManojBajpayee, SamanthaAkkineni, Priyamani, S...
# 1     [TomEllis, LaurenGerman, Lesley-AnnBrandt, Kev...
# 2     [ElisabethMoss, YvonneStrahovski, JosephFienne...
# 3     [AdamBrody, EdiGathegi, OtmaraMarrero, Kristen...
# 4     [EmiliaClarke, PeterDinklage, KitHarington, Le...
# ...                                                 ...
# 2975  [MischaBarton, BenjaminHollingsworth, SaraPaxt...
# 2976  [CharlesRoot, JohnM.Kelley, JamesCawley, JeffM...
# 2977  [ChristopherCox, OliviaDiNino, BenjaminHsieh, ...
# 2978  [RyanHansen, AlyMichalka, SamiraWiley, NoelleE...
# 2979  [KatherineHeigl, DuléHill, LaverneCox, DreamaW...
#
# [2980 rows x 4 columns]

# %%
df_new['tags'] = df_new['About'] + df_new['Genres'] + df_new['Actors']

# %%
df_new
# Out:
#                                         Title  \
# 0                              The Family Man
# 1                                     Lucifer
# 2                         The Handmaid's Tale
# 3                                     StartUp
# 4                             Game of Thrones
# ...                                       ...
# 2975                  The Beautiful Life: TBL
# 2976                   Star Trek: New Voyages
# 2977                                    Panic
# 2978  Ryan Hansen Solves Crimes on Television
# 2979                                    Doubt
#
#                                                   About  \
# 0     [A, working, man, from, the, National, Investi...
# 1     [Lucifer, Morningstar, has, decided, he's, had...
# 2     [Set, in, a, dystopian, future, a, woman, is, ...
# 3     [A, desperate, banker, a, Haitian-American, ga...
# 4     [Nine, noble, families, fight, for, control, o...
# ...                                                 ...
# 2975  [Meet, Sam, a, lonely, teenager, struggling, t...
# 2976  [In, a, world, where, Hollywood, actors, can, ...
# 2977  [A, successful, defense, lawyer, at, a, boutiq...
# 2978  [A, comedy, centered, around, six, 30-somethin...
# 2979  [Romantic, anthology, web, series, revolving, ...
#
#                            Genres  \
# 0         [Action, Comedy, Drama]
# 1         [Crime, Drama, Fantasy]
# 2       [Drama, Sci-Fi, Thriller]
# 3               [Crime, Thriller]
# 4      [Action, Adventure, Drama]
# ...                           ...
# 2975                      [Drama]
# 2976  [Action, Adventure, Sci-Fi]
# 2977              [Comedy, Drama]
# 2978      [Action, Comedy, Crime]
# 2979                      [Drama]
#
#                                                  Actors  \
# 0     [ManojBajpayee, SamanthaAkkineni, Priyamani, S...
# 1     [TomEllis, LaurenGerman, Lesley-AnnBrandt, Kev...
# 2     [ElisabethMoss, YvonneStrahovski, JosephFienne...
# 3     [AdamBrody, EdiGathegi, OtmaraMarrero, Kristen...
# 4     [EmiliaClarke, PeterDinklage, KitHarington, Le...
# ...                                                 ...
# 2975  [MischaBarton, BenjaminHollingsworth, SaraPaxt...
# 2976  [CharlesRoot, JohnM.Kelley, JamesCawley, JeffM...
# 2977  [ChristopherCox, OliviaDiNino, BenjaminHsieh, ...
# 2978  [RyanHansen, AlyMichalka, SamiraWiley, NoelleE...
# 2979  [KatherineHeigl, DuléHill, LaverneCox, DreamaW...
#
#                                                    tags
# 0     [A, working, man, from, the, National, Investi...
# 1     [Lucifer, Morningstar, has, decided, he's, had...
# 2     [Set, in, a, dystopian, future, a, woman, is, ...
# 3     [A, desperate, banker, a, Haitian-American, ga...
# 4     [Nine, noble, families, fight, for, control, o...
# ...                                                 ...
# 2975  [Meet, Sam, a, lonely, teenager, struggling, t...
# 2976  [In, a, world, where, Hollywood, actors, can, ...
# 2977  [A, successful, defense, lawyer, at, a, boutiq...
# 2978  [A, comedy, centered, around, six, 30-somethin...
# 2979  [Romantic, anthology, web, series, revolving, ...
#
# [2980 rows x 5 columns]

# %%
df_final = df_new[['Title', 'tags']]

# %%
df_final['Rating'] = df_new['Rating']
df_final['About'] = df_new['About']
df_final
# Out:
# <ipython-input-157-b876c7a55574>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rating'] = df_new['Rating']
# <ipython-input-157-b876c7a55574>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['About'] = df_new['About']
#                                         Title  \
# 0                              The Family Man
# 1                                     Lucifer
# 2                         The Handmaid's Tale
# 3                                     StartUp
# 4                             Game of Thrones
# ...                                       ...
# 2975                  The Beautiful Life: TBL
# 2976                   Star Trek: New Voyages
# 2977                                    Panic
# 2978  Ryan Hansen Solves Crimes on Television
# 2979                                    Doubt
#
#                                                    tags  Rating  \
# 0     a work man from the nation investig agenc tri ...     8.8
# 1     lucif morningstar ha decid he' had enough of b...     8.1
# 2     set in a dystopian futur a woman is forc to li...     8.4
# 3     a desper banker a haitian-american gang lord a...     8.0
# 4     nine nobl famili fight for control over the la...     9.3
# ...                                                 ...     ...
# 2975  meet sam a lone teenag struggl through colleg ...     6.4
# 2976  in a world where hollywood actor can partner u...     8.0
# 2977  a success defens lawyer at a boutiqu firm beco...     6.4
# 2978  a comedi center around six 30-someth friend wh...     7.9
# 2979  romant antholog web seri revolv around 12 stor...     7.2
#
#                                                   About
# 0     A working man from the National Investigation ...
# 1     Lucifer Morningstar has decided he's had enoug...
# 2     Set in a dystopian future, a woman is forced t...
# 3     A desperate banker, a Haitian-American gang lo...
# 4     Nine noble families fight for control over the...
# ...                                                 ...
# 2975  Ayvalik is brought into play by the mob from a...
# 2976  The early life of Bobby McCallister, a progres...
# 2977  A relationship-advice guru, upon learning that...
# 2978  When a young couple inherit a farm, they are d...
# 2979  As the Medellin Cartel crumbles, Pablo Escobar...
#
# [2980 rows x 4 columns]

# %%
df_final['tags'] = df_final['tags'].apply(lambda x: " ".join(x))
# Out:
# <ipython-input-105-1d8ffe5e206a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tags'] = df_final['tags'].apply(lambda x: " ".join(x))

# %%
df_final['tags'] = df_final['tags'].apply(lambda x: x.lower())
# Out:
# <ipython-input-109-07f8fb5364f3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tags'] = df_final['tags'].apply(lambda x: x.lower())

# %%
df_final.head()
# Out:
#                  Title                                               tags
# 0       The Family Man  a working man from the national investigation ...
# 1              Lucifer  lucifer morningstar has decided he's had enoug...
# 2  The Handmaid's Tale  set in a dystopian future a woman is forced to...
# 3              StartUp  a desperate banker a haitian-american gang lor...
# 4      Game of Thrones  nine noble families fight for control over the...

# %% [markdown]
# ## Using Vectorizer and Cosine similarity to find similairity between tv shows

# %%
cv = CountVectorizer(max_features = 5000, stop_words = 'english')

# %%
#vectorizing our tags
vectors = cv.fit_transform(df_final['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
#getting our most frequently used words
cv.get_feature_names()
# Out:
# ['10',
#  '100',
#  '11',
#  '12',
#  '13',
#  '13th',
#  '14',
#  '15',
#  '16',
#  '16th',
#  '17',
#  '17th',
#  '18',
#  '1800s',
#  '1871',
#  '19',
#  '1900s',
#  '1905',
#  '1920s',
#  '1940s',
#  '1943',
#  '1945',
#  '1950s',
#  '1960s',
#  '1969',
#  '1970s',
#  '1980',
#  '1980s',
#  '1984',
#  '1990',
#  '1990s',
#  '1996',
#  '19th',
#  '20',
#  '2001',
#  '2015',
#  '2016',
#  '20s',
#  '20th',
#  '21',
#  '21st',
#  '24',
#  '25',
#  '26',
#  '28',
#  '30',
#  '300',
#  '30s',
#  '40',
#  '40s',
#  '50',
#  '60',
#  '800',
#  '80s',
#  '8th',
#  '90',
#  '90s',
#  'aaron',
#  'aarondismuke',
#  'aaronpaul',
#  'aaronpedersen',
#  'aasifmandvi',
#  'abandoned',
#  'abbiecornish',
#  'abby',
#  'abbytrott',
#  'abc',
#  'abiding',
#  'abigailspencer',
#  'abilities',
#  'ability',
#  'able',
#  'aboard',
#  'abolitionist',
#  'abroad',
#  'absence',
#  'absurd',
#  'abuse',
#  'academy',
#  'accept',
#  'accepts',
#  'accident',
#  'accidentally',
#  'acclaimed',
#  'accompanied',
#  'account',
#  'accountant',
#  'accounts',
#  'accusations',
#  'accused',
#  'acero',
#  'achieve',
#  'acosta',
#  'acquired',
#  'acre',
#  'act',
#  'acting',
#  'action',
#  'actions',
#  'activities',
#  'activity',
#  'actor',
#  'actors',
#  'actress',
#  'acts',
#  'actually',
#  'ad',
#  'adam',
#  'adambrody',
#  'adamcampbell',
#  'adamdevine',
#  'adamgibbs',
#  'adamgodley',
#  'adamhicks',
#  'adamrayner',
#  'adamrichman',
#  'adamscott',
#  'adapt',
#  'adaptation',
#  'add',
#  'addicted',
#  'addition',
#  'adeelakhtar',
#  'adjust',
#  'adolescent',
#  'adopted',
#  'adoption',
#  'adrianaugarte',
#  'adriandunbar',
#  'adrianholmes',
#  'adult',
#  'adulthood',
#  'adults',
#  'advanced',
#  'adventure',
#  'adventurer',
#  'adventures',
#  'adventurous',
#  'advice',
#  'advisor',
#  'affair',
#  'affairs',
#  'affected',
#  'affluence',
#  'affluent',
#  'african',
#  'afterlife',
#  'aftermath',
#  'age',
#  'aged',
#  'agencies',
#  'agency',
#  'agent',
#  'agents',
#  'ages',
#  'aging',
#  'ago',
#  'ah',
#  'aid',
#  'aidangillen',
#  'aids',
#  'aikayano',
#  'aim',
#  'aimeecarrero',
#  'aimeeteegarden',
#  'aims',
#  'air',
#  'aislingbea',
#  'aka',
#  'akenowatanabe',
#  'akioôtsuka',
#  'akitoyosaki',
#  'al',
#  'alan',
#  'alanadelagarza',
#  'alannaubach',
#  'alanritchson',
#  'alantudyk',
#  'alaska',
#  'alaskan',
#  'albertoammann',
#  'alchemical',
#  'alcoholic',
#  'aldishodge',
#  'alex',
#  'alexa',
#  'alexadavies',
#  'alexander',
#  'alexandrabreckenridge',
#  'alexandrarapaport',
#  'alexborstein',
#  'alexiscarra',
#  'alexistipton',
#  'alexlogan',
#  'alexoloughlin',
#  'alfonsoherrera',
#  'alfred',
#  'ali',
#  'alien',
#  'aliens',
#  'alinaboz',
#  'alisonbrie',
#  'alive',
#  'aliwong',
#  'allegedly',
#  'alliance',
#  'allies',
#  'allison',
#  'allisonmiller',
#  'allisontolman',
#  'allows',
#  'ally',
#  'allynrachel',
#  'alongside',
#  'alter',
#  'alternate',
#  'alternative',
#  'alysonhannigan',
#  'amaiasalamanca',
#  'amanda',
#  'amandaleighton',
#  'amandapeet',
#  'amateur',
#  'amaurynolasco',
#  'amazing',
#  'amber',
#  'amberleeconnors',
#  'ambition',
#  'ambitions',
#  'ambitious',
#  'america',
#  'americaferrera',
#  'american',
#  'americans',
#  'amid',
#  'amidst',
#  'amnesia',
#  'amsterdam',
#  'amy',
#  'amyhuberman',
#  'amysedaris',
#  'anafabrega',
#  'analyst',
#  'anaortiz',
#  'anastasiagriffith',
#  'anatomy',
#  'anchor',
#  'ancient',
#  'anderson',
#  'andreaanders',
#  'andreamartin',
#  'andrew',
#  'andrewrannells',
#  'android',
#  'andy',
#  'andyrichter',
#  'anedahltorp',
#  'angelako',
#  'angeles',
#  'angelica',
#  'angels',
#  'anger',
#  'angers',
#  'angélicacelaya',
#  'anikanonirose',
#  'animal',
#  'animals',
#  'animated',
#  'animation',
#  'ankilidén',
#  'annadiop',
#  'annafriel',
#  'annamaxwellmartin',
#  'annapaquin',
#  'annatorv',
#  'anne',
#  'anneheche',
#  'annie',
#  'anniemurphy',
#  'announcer',
#  'anonymous',
#  'ansonmount',
#  'answer',
#  'answering',
#  'answers',
#  'anthology',
#  'anthony',
#  'anthonybourdain',
#  'anthropomorphic',
#  'anti',
#  'antics',
#  'antoniaprebble',
#  'antonyelchin',
#  'antonystarr',
#  'antwerp',
#  'anxieties',
#  'anymore',
#  'apart',
#  'apartment',
#  'apocalypse',
#  'apocalyptic',
#  'app',
#  'appear',
#  'appearance',
#  'appeared',
#  'appears',
#  'apple',
#  'applies',
#  'apply',
#  'apprentice',
#  'approach',
#  'arasbulutiynemli',
#  'arcadia',
#  'archaeological',
#  'archie',
#  'archipelago',
#  'architect',
#  'arctic',
#  'ardalanesmaili',
#  'area',
#  'aren',
#  'armed',
#  'army',
#  'array',
#  'arrest',
#  'arrested',
#  'arrival',
#  'arrive',
#  'arrives',
#  'art',
#  'artemispebdani',
#  'arthur',
#  'artifacts',
#  'artificial',
#  'artist',
#  'artists',
#  'arts',
#  'asamiseto',
#  'ashleighball',
#  'ashleighcummings',
#  'ashleyjensen',
#  'ashleyjohnson',
#  'ashleyscott',
#  'ashleytisdale',
#  'ashlyburch',
#  'ashtonkutcher',
#  'ask',
#  'asked',
#  'asks',
#  'aspirations',
#  'aspire',
#  'aspires',
#  'aspiring',
#  'assassin',
#  'assassination',
#  'assassins',
#  'assigned',
#  'assignment',
#  'assignments',
#  'assistance',
#  'assistant',
#  'associates',
#  'assume',
#  'assumes',
#  'asteroid',
#  'astronaut',
#  'asylum',
#  'atlanta',
#  'atlantic',
#  'atoessandoh',
#  'atsumitanezaki',
#  'attack',
#  'attacked',
#  'attacks',
#  'attempt',
#  'attempted',
#  'attempting',
#  'attempts',
#  'attend',
#  'attended',
#  'attending',
#  'attention',
#  'attitude',
#  'attorney',
#  'attorneys',
#  'attracted',
#  'attractive',
#  'aubreydollar',
#  'audience',
#  'audrey',
#  'audreyfleurot',
#  'audreymarieanderson',
#  'audrinapatridge',
#  'aunt',
#  'aurora',
#  'auroraperrineau',
#  'austin',
#  'australia',
#  'australian',
#  'australians',
#  'author',
#  'authority',
#  'autism',
#  'autobiographical',
#  'avanjogia',
#  'avatar',
#  'avenge',
#  'average',
#  'avoid',
#  'awakened',
#  'awakens',
#  'award',
#  'away',
#  'awkward',
#  'ayakokawasumi',
#  'ayanesakura',
#  'ayumumurase',
#  'baby',
#  'bachelor',
#  'bachelorette',
#  'backdrop',
#  'background',
#  'backgrounds',
#  'bad',
#  'baedoona',
#  'baesuzy',
#  'bahar',
#  'baileydeyoung',
#  'baker',
#  'bakers',
#  'balance',
#  'ball',
#  'bam',
#  'band',
#  'bang',
#  'banker',
#  'banks',
#  'banshee',
#  'baptiste',
#  'bar',
#  'barca',
#  'barcelona',
#  'barisarduç',
#  'barisfalay',
#  'baron',
#  'barrysloane',
#  'bars',
#  'bartender',
#  'base',
#  'baseball',
#  'based',
#  'basis',
#  'basketball',
#  'batman',
#  'battle',
#  'battles',
#  'battling',
#  'baxter',
#  'bay',
#  'bbc',
#  'beach',
#  'beacon',
#  'bear',
#  'beast',
#  'beat',
#  'beats',
#  'beaugarrett',
#  'beaumirchoff',
#  'beautiful',
#  'beauty',
#  'becca',
#  'bedroom',
#  'bee',
#  'beer',
#  'befriends',
#  'began',
#  'begin',
#  'beginning',
#  'beginnings',
#  'begins',
#  'behalf',
#  'behavior',
#  'beings',
#  'believe',
#  'believers',
#  'believes',
#  'belle',
#  'beloved',
#  'ben',
#  'bendiskin',
#  'beneath',
#  'benschwartz',
#  'bensinclair',
#  'bent',
#  'berensaat',
#  'berlin',
#  'best',
#  'bestselling',
#  'betrayal',
#  'betrayed',
#  'betsybrandt',
#  'better',
#  'beverly',
#  'biancakajlich',
#  'big',
#  'bigger',
#  'biggest',
#  'billfarmer',
#  'billionaire',
#  'billpaterson',
#  'billpaxton',
#  'billy',
#  'billybobthornton',
#  'billycampbell',
#  'billycrudup',
#  'billygardell',
#  'bin',
#  'binkim',
#  'bio',
#  'biography',
#  'biological',
#  'biology',
#  'bionic',
#  'birceakalay',
#  'bird',
#  'birgittehjortsørensen',
#  'birth',
#  'birthday',
#  'bishop',
#  'bit',
#  'bite',
#  'bizarre',
#  'bjørn',
#  'black',
#  'blancasuárez',
#  'blend',
#  'blind',
#  'block',
#  'blogger',
#  'blood',
#  'bloody',
#  'blue',
#  'bo',
#  'board',
#  'boarding',
#  'boat',
#  'bob',
#  'bobbergen',
#  'bobby',
#  'bobbyflay',
#  'bobbymoynihan',
#  'bobodenkirk',
#  'bodies',
#  'body',
#  'bodyguard',
#  'bogotá',
#  'bomb',
#  'bond',
#  'bonded',
#  'bong',
#  'boo',
#  'book',
#  'books',
#  'border',
#  'borders',
#  'born',
#  'boss',
#  'boston',
#  'bounty',
#  'bourdain',
#  'bourne',
#  'bow',
#  'box',
#  'boxing',
#  'boy',
#  'boyfriend',
#  'boys',
#  'bradleyjames',
#  'bradleystevenperry',
#  'bradleywhitford',
#  'brady',
#  'brain',
#  'branches',
#  'brand',
#  'brandonmychalsmith',
#  'brandonpbell',
#  'brave',
#  'brazil',
#  'break',
#  'breaking',
#  'breaks',
#  'breakthrough',
#  'breannayde',
#  'breckinmeyer',
#  'brendanscannell',
#  'brendasong',
#  'brennanelliott',
#  'brentbutt',
#  'bret',
#  'brettdier',
#  'brettgelman',
#  'brian',
#  'brianbeacock',
#  'briancox',
#  'briangleeson',
#  'brianj',
#  'bride',
#  'bridge',
#  'bridget',
#  'bridgitmendler',
#  'brief',
#  'brigaheelan',
#  'bright',
#  'brilliant',
#  'brinapalencia',
#  'bring',
#  'bringing',
#  'brings',
#  'brink',
#  'britain',
#  'british',
#  'brittanysnow',
#  'brittlower',
#  'brittneykarbowski',
#  'brittrobertson',
#  'broadway',
#  'broken',
#  'brokers',
#  'brookedorsay',
#  'brothel',
#  'brother',
#  'brothers',
#  'brought',
#  'brown',
#  'brucedavison',
#  'brucegreenwood',
#  'brutal',
#  'brutally',
#  'bryancranston',
#  'brycepapenbrook',
#  'brysonbaugus',
#  'buckley',
#  'buddy',
#  'budget',
#  'bugragülsoy',
#  'build',
#  'building',
#  'built',
#  'bullied',
#  'bunny',
#  'burakdeniz',
#  'burcuözberk',
#  'bureau',
#  'buried',
#  'burçinterzioglu',
#  'bus',
#  'bush',
#  'business',
#  'businessman',
#  'bustle',
#  'busy',
#  'butcher',
#  'butler',
#  'butterfly',
#  'buy',
#  'buyers',
#  'byrne',
#  'caglarertugrul',
#  'caitlinglass',
#  'calamity',
#  'california',
#  'called',
#  'calling',
#  'calls',
#  'came',
#  'camera',
#  'cameron',
#  'camp',
#  'campaign',
#  'canada',
#  'canadian',
#  'canberra',
#  'cancer',
#  'candacecameronbure',
#  'candice',
#  'cannabis',
#  'cap',
#  'capable',
#  'cape',
#  'capital',
#  'captain',
#  'capture',
#  'captured',
#  'car',
#  'care',
#  'career',
#  'careers',
#  'carefree',
#  'cares',
#  'carlagugino',
#  'carllumbly',
#  'carloscuevas',
#  'carlospenavega',
#  'carly',
#  'carlychaikin',
#  'carol',
#  'carolina',
#  'carolinedhavernas',
#  'carrelllasso',
#  'carrie',
#  'carry',
#  'cars',
#  'carsonkressley',
#  'cartel',
#  'carter',
#  'case',
#  'cases',
#  'casey',
#  'cash',
#  'casino',
#  'cassie',
#  'cast',
#  'castle',
#  'cat',
#  'catch',
#  'catherine',
#  'catherinetaber',
#  'catholic',
#  'cattle',
#  'caught',
#  'cause',
#  'caused',
#  'causes',
#  'causing',
#  'cedricyarbrough',
#  'celebrate',
#  'celebrities',
#  'celebrity',
#  'celia',
#  'cell',
#  'center',
#  'centered',
#  'centering',
#  'centers',
#  'central',
#  'centre',
#  'centres',
#  'centuries',
#  'century',
#  'ceo',
#  'certain',
#  'chadmichaelmurray',
#  'chaesoo',
#  'chaeun',
#  'chagrin',
#  'chaihansen',
#  'chain',
#  'challenge',
#  'challenged',
#  'challenges',
#  'challenging',
#  'champion',
#  'championship',
#  'chance',
#  'change',
#  'changed',
#  'changes',
#  'changing',
#  'channel',
#  'chaos',
#  'chapman',
#  'character',
#  'characters',
#  'charge',
#  'charged',
#  'charismatic',
#  'charles',
#  'charlesdeath',
#  'charlie',
#  'charliemurphy',
#  'charlieryan',
#  'charliesaxton',
#  'charlieschlatter',
#  'charlotteritchie',
#  'charming',
#  'charter',
#  'chase',
#  'chasing',
#  'cheating',
#  'chef',
#  'chefs',
#  'chelsea',
#  'chelseakane',
#  'chemical',
#  'chemistry',
#  'cheramileigh',
#  'chicago',
#  'chicken',
#  'chief',
#  'chihuahua',
#  'chikahirokobayashi',
#  'child',
#  'childhood',
#  'childish',
#  'children',
#  'chilling',
#  'chimcbride',
#  'china',
#  'chiwasaitô',
#  'chloe',
#  'chloësevigny',
#  'choi',
#  'choose',
#  'chooses',
#  'chosen',
#  'chris',
#  'chrisdelia',
#  'chrisdiamantopoulos',
#  'chrisharrison',
#  'chrisodowd',
#  'christ',
#  'christianslater',
#  'christinaricci',
#  'christmas',
#  'christopherbevins',
#  'christophergorham',
#  'christophermcculloch',
#  'christophermintz',
#  'christophersabat',
#  'chronicle',
#  'chronicles',
#  'chronicling',
#  'church',
#  'chylerleigh',
#  'cia',
#  'ciarabravo',
#  'circle',
#  'circumstances',
#  'cities',
#  'citizen',
#  'citizens',
#  'city',
#  'civil',
#  'civilians',
#  'civilization',
#  'claim',
#  'clan',
#  'clandestine',
#  'clark',
#  'clarkduke',
#  'clarkgregg',
#  'clash',
#  'clashes',
#  'clashing',
#  'class',
#  'classes',
#  'classic',
#  'classmate',
#  'classmates',
#  'classroom',
#  'clean',
#  'cleaning',
#  'clear',
#  'clever',
#  'client',
#  'clients',
#  'cliff',
#  'climb',
#  'cliveowen',
#  'clock',
#  'close',
#  'closed',
#  'closer',
#  'closest',
#  'clothes',
#  'club',
#  'clues',
#  'coach',
#  'coal',
#  'coast',
#  'coastal',
#  'cobiesmulders',
#  'code',
#  'cody',
#  'coined',
#  'cold',
#  'colehauser',
#  'colesprouse',
#  'colin',
#  'colinhanks',
#  'colinmorgan',
#  'collar',
#  'colleague',
#  'colleagues',
#  'collect',
#  'collecting',
#  'collection',
#  'college',
#  'collide',
#  'colliding',
#  'colmmeaney',
#  'colombia',
#  'colombian',
#  'colorado',
#  'colorful',
#  'coma',
#  'combat',
#  'combination',
#  'come',
#  'comedian',
#  'comedians',
#  'comedic',
#  'comedy',
#  'comes',
#  'comic',
#  'comically',
#  'comics',
#  'coming',
#  'commander',
#  'commit',
#  'commitment',
#  'committed',
#  'committing',
#  'common',
#  'communicate',
#  'communicates',
#  'communication',
#  'communist',
#  'community',
#  'companies',
#  'companion',
#  'companions',
#  'company',
#  'compelling',
#  'compete',
#  'competent',
#  'competes',
#  'competing',
#  'competition',
#  'competitive',
#  'complete',
#  'completely',
#  'complex',
#  'complicated',
#  'complications',
#  'compton',
#  'compulsive',
#  'computer',
#  'conceal',
#  'concierge',
#  'concubine',
#  'confederate',
#  'confession',
#  'confident',
#  'conflict',
#  'conflicts',
#  'confront',
#  'confronted',
#  'connect',
#  'connected',
#  'connection',
#  'connections',
#  'connects',
#  'conquer',
#  'cons',
#  'conscience',
#  'consequences',
#  'consists',
#  'conspiracies',
#  'conspiracy',
#  'constancemarie',
#  'constant',
#  'constantly',
#  'construction',
#  'consultant',
#  'contact',
#  'contains',
#  'contemporary',
#  'content',
#  'contest',
#  'contestants',
#  'continuation',
#  'continue',
#  'continues',
#  'continuing',
#  'contract',
#  'contracts',
#  'contrast',
#  'control',
#  'controversial',
#  'convicted',
#  'conviction',
#  'convinced',
#  'cook',
#  'cooking',
#  'cooks',
#  'cool',
#  'cooper',
#  'cop',
#  'cope',
#  ...]

# %%
#applying stemming to get rid of words that are similar to one another and replace them with the same names
ps = PorterStemmer()
def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
df_final['tags'] = df_final['tags'].apply(stem)
# Out:
# <ipython-input-122-6a724de61b17>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tags'] = df_final['tags'].apply(stem)

# %%
#vectorizing our tags
vectors = cv.fit_transform(df_final['tags']).toarray()

# %%
#getting our most frequently used words
cv.get_feature_names()
# Out:
# ['10',
#  '100',
#  '10000',
#  '11',
#  '12',
#  '13',
#  '13th',
#  '14',
#  '15',
#  '16',
#  '16th',
#  '17',
#  '17th',
#  '18',
#  '1800',
#  '1871',
#  '19',
#  '1905',
#  '1920',
#  '1930',
#  '1940s',
#  '1943',
#  '1945',
#  '1950',
#  '1950s',
#  '1960',
#  '1960s',
#  '1969',
#  '1970',
#  '1970s',
#  '1980',
#  '1980s',
#  '1984',
#  '1990',
#  '1990s',
#  '1996',
#  '19th',
#  '20',
#  '2000',
#  '2001',
#  '2005',
#  '2016',
#  '20th',
#  '21st',
#  '23',
#  '24',
#  '25',
#  '26',
#  '28',
#  '30',
#  '300',
#  '40',
#  '50',
#  '60',
#  '80',
#  '800',
#  '8th',
#  '90',
#  'aaron',
#  'aarondismuk',
#  'aaronpaul',
#  'aaronpedersen',
#  'aaronstanford',
#  'aasifmandvi',
#  'abandon',
#  'abbi',
#  'abbiecornish',
#  'abbijacobson',
#  'abbydonnelli',
#  'abbytrott',
#  'abc',
#  'abduct',
#  'abigailspenc',
#  'abil',
#  'abilities',
#  'abl',
#  'aboard',
#  'abolitionist',
#  'abov',
#  'absenc',
#  'absorb',
#  'absurd',
#  'abus',
#  'academi',
#  'academy',
#  'accept',
#  'access',
#  'accid',
#  'accident',
#  'acclaim',
#  'accompani',
#  'account',
#  'accus',
#  'acero',
#  'achiev',
#  'acquir',
#  'act',
#  'action',
#  'activ',
#  'activities',
#  'activity',
#  'actor',
#  'actors',
#  'actress',
#  'actual',
#  'ad',
#  'adam',
#  'adamdevin',
#  'adamgibb',
#  'adamgodley',
#  'adamhick',
#  'adamrayn',
#  'adamscott',
#  'adapt',
#  'add',
#  'addict',
#  'addit',
#  'address',
#  'adeelakhtar',
#  'adelayoadedayo',
#  'adjust',
#  'adolesc',
#  'adopt',
#  'adriandunbar',
#  'adriennebarbeau',
#  'adult',
#  'adulthood',
#  'advanc',
#  'adventur',
#  'adventure',
#  'adventures',
#  'advic',
#  'advice',
#  'advisor',
#  'affair',
#  'affect',
#  'affluenc',
#  'affluent',
#  'afford',
#  'afghanistan',
#  'africa',
#  'african',
#  'aftermath',
#  'ag',
#  'age',
#  'agenc',
#  'agent',
#  'ago',
#  'agre',
#  'ah',
#  'ahead',
#  'ahnjae',
#  'aid',
#  'aidangillen',
#  'aidanturn',
#  'aikayano',
#  'aim',
#  'aimeecarrero',
#  'aimeeteegarden',
#  'air',
#  'airlin',
#  'aislinnpaul',
#  'aka',
#  'akenowatanab',
#  'akil',
#  'akioôtsuka',
#  'akitoyosaki',
#  'al',
#  'alan',
#  'alanadelagarza',
#  'alannaubach',
#  'alanritchson',
#  'alantudyk',
#  'alaska',
#  'alaskan',
#  'albert',
#  'albertoammann',
#  'alchem',
#  'alcohol',
#  'alemdar',
#  'alex',
#  'alexa',
#  'alexand',
#  'alexandrabreckenridg',
#  'alexandrarapaport',
#  'alexhirsch',
#  'alexistipton',
#  'alexlogan',
#  'alfonsoherrera',
#  'alfr',
#  'ali',
#  'alicia',
#  'alien',
#  'alisonbri',
#  'aliv',
#  'alive',
#  'aliwong',
#  'alli',
#  'allianc',
#  'allisonmil',
#  'allisontolman',
#  'allow',
#  'alon',
#  'alongsid',
#  'alpha',
#  'alreadi',
#  'alter',
#  'altern',
#  'alway',
#  'alymichalka',
#  'alysonhannigan',
#  'alyssa',
#  'amaiasalamanca',
#  'amanda',
#  'amandaabbington',
#  'amandacerni',
#  'amandaleighton',
#  'amandapeet',
#  'amandaredman',
#  'amass',
#  'amateur',
#  'amaz',
#  'amazon',
#  'amber',
#  'amberfrank',
#  'amberleeconnor',
#  'ambigu',
#  'ambit',
#  'ambiti',
#  'america',
#  'americaferrera',
#  'american',
#  'ami',
#  'amidst',
#  'amnesia',
#  'amphibia',
#  'amsterdam',
#  'amulet',
#  'amyhuberman',
#  'amypoehl',
#  'amysedari',
#  'ana',
#  'analyst',
#  'analyz',
#  'anand',
#  'anaortiz',
#  'anastasiagriffith',
#  'anastasiahil',
#  'ancestor',
#  'anchor',
#  'ancient',
#  'anderson',
#  'andi',
#  'andreaand',
#  'andrew',
#  'andrewlincoln',
#  'andrewrannel',
#  'android',
#  'andré',
#  'angel',
#  'angelabassett',
#  'angelako',
#  'angeles',
#  'angelica',
#  'anger',
#  'angi',
#  'angri',
#  'angussampson',
#  'angélicacelaya',
#  'ani',
#  'anikanoniros',
#  'anim',
#  'animation',
#  'ankilidén',
#  'ann',
#  'annachancellor',
#  'annafriel',
#  'annakonkl',
#  'annapaquin',
#  'annatorv',
#  'anneburrel',
#  'annehech',
#  'annemoss',
#  'anni',
#  'anniemurphi',
#  'announc',
#  'annoy',
#  'anonym',
#  'anoth',
#  'ansonmount',
#  'answer',
#  'antholog',
#  'anthoni',
#  'anti',
#  'antic',
#  'anticip',
#  'antiqu',
#  'antisoci',
#  'antoniaprebbl',
#  'antoniathoma',
#  'antonyelchin',
#  'antonystarr',
#  'antwerp',
#  'anxieti',
#  'anymor',
#  'anyon',
#  'anyth',
#  'apart',
#  'apocalyps',
#  'apocalypse',
#  'apocalypt',
#  'app',
#  'appear',
#  'appearance',
#  'appetit',
#  'appli',
#  'appoint',
#  'apprentic',
#  'approach',
#  'arasbulutiynemli',
#  'arcadia',
#  'archaeolog',
#  'archi',
#  'archipelago',
#  'architect',
#  'arctic',
#  'area',
#  'aren',
#  'arena',
#  'ariellekebbel',
#  'arigraynor',
#  'aris',
#  'aristocrat',
#  'armi',
#  'army',
#  'arrang',
#  'array',
#  'arrest',
#  'arriv',
#  'arrog',
#  'arsherali',
#  'art',
#  'artemispebdani',
#  'arthur',
#  'artifacts',
#  'artifici',
#  'artist',
#  'asamiseto',
#  'ash',
#  'asherkeddi',
#  'ashleighbal',
#  'ashleighcum',
#  'ashleyjensen',
#  'ashleyjohnson',
#  'ashleyscott',
#  'ashleytisdal',
#  'ashleywalt',
#  'ashleyzukerman',
#  'ashlyburch',
#  'ask',
#  'aspir',
#  'assassin',
#  'assassins',
#  'assembl',
#  'assign',
#  'assist',
#  'assistant',
#  'associates',
#  'assort',
#  'assum',
#  'asteroid',
#  'astronaut',
#  'asylum',
#  'athelstan',
#  'athenakarkani',
#  'atlant',
#  'atlanta',
#  'atoessandoh',
#  'atom',
#  'attack',
#  'attacks',
#  'attempt',
#  'attend',
#  'attent',
#  'atticusshaff',
#  'attitude',
#  'attorney',
#  'attract',
#  'audienc',
#  'audrey',
#  'audreyfleurot',
#  'audreymarieanderson',
#  'audrinapatridg',
#  'aunt',
#  'aurora',
#  'auroraperrineau',
#  'austin',
#  'australia',
#  'australian',
#  'author',
#  'autism',
#  'autist',
#  'autobiograph',
#  'avanjogia',
#  'aveng',
#  'averag',
#  'avoid',
#  'await',
#  'awaken',
#  'award',
#  'away',
#  'awkward',
#  'ayanesakura',
#  'ayumumuras',
#  'açelyatopaloglu',
#  'babi',
#  'bachelor',
#  'bachelorett',
#  'backdrop',
#  'background',
#  'backstag',
#  'backyard',
#  'bad',
#  'baedoona',
#  'baesuzi',
#  'baffl',
#  'bag',
#  'bahar',
#  'baker',
#  'baki',
#  'balanc',
#  'balance',
#  'ball',
#  'ballet',
#  'bam',
#  'band',
#  'bang',
#  'bank',
#  'baptist',
#  'bar',
#  'barbaraniven',
#  'barca',
#  'barcelona',
#  'bargain',
#  'barisarduç',
#  'barisfalay',
#  'baron',
#  'baronvaughn',
#  'barri',
#  'barrysloan',
#  'bartend',
#  'bas',
#  'base',
#  'basebal',
#  'basi',
#  'basketbal',
#  'batman',
#  'battl',
#  'baxter',
#  'bay',
#  'bea',
#  'beach',
#  'bean',
#  'bear',
#  'beast',
#  'beat',
#  'beatieedney',
#  'beaugarrett',
#  'beauti',
#  'becam',
#  'becaus',
#  'becca',
#  'becom',
#  'bedroom',
#  'bee',
#  'beer',
#  'befor',
#  'befriend',
#  'began',
#  'begin',
#  'begins',
#  'behalf',
#  'behavior',
#  'beings',
#  'believ',
#  'bell',
#  'bellathorn',
#  'belov',
#  'belt',
#  'ben',
#  'bendiskin',
#  'beneath',
#  'benedictwong',
#  'benfeldman',
#  'benschwartz',
#  'bensinclair',
#  'bent',
#  'benwhishaw',
#  'berensaat',
#  'berlin',
#  'best',
#  'bestsel',
#  'betray',
#  'betsybrandt',
#  'better',
#  'beverli',
#  'bextaylor',
#  'bff',
#  'biancakajlich',
#  'big',
#  'bigg',
#  'bigger',
#  'biggest',
#  'bike',
#  'billfarm',
#  'billi',
#  'billion',
#  'billionair',
#  'billpaterson',
#  'billpaxton',
#  'billybobthornton',
#  'billyburk',
#  'billycampbel',
#  'billygardel',
#  'bin',
#  'bio',
#  'biographi',
#  'biolog',
#  'bionic',
#  'birceakalay',
#  'bird',
#  'birgittehjortsørensen',
#  'birth',
#  'birthday',
#  'birthright',
#  'bishop',
#  'bit',
#  'bite',
#  'bizarr',
#  'bjørn',
#  'black',
#  'blackmail',
#  'blake',
#  'blame',
#  'blancasuárez',
#  'blend',
#  'blind',
#  'block',
#  'blockbust',
#  'blood',
#  'bloodi',
#  'blow',
#  'blue',
#  'bo',
#  'board',
#  'boat',
#  'bob',
#  'bobbergen',
#  'bobbi',
#  'bobbycannaval',
#  'bobbyflay',
#  'bobbymoynihan',
#  'bobodenkirk',
#  'bodi',
#  'body',
#  'bodyguard',
#  'bold',
#  'bomb',
#  'bond',
#  'bones',
#  'bong',
#  'book',
#  'boom',
#  'border',
#  'bore',
#  'born',
#  'boruto',
#  'boss',
#  'boston',
#  'bounti',
#  'bourn',
#  'bow',
#  'box',
#  'boy',
#  'boyfriend',
#  'boys',
#  'bradleyjam',
#  'bradleystevenperri',
#  'bradleywalsh',
#  'bradleywhitford',
#  'brain',
#  'branch',
#  'brand',
#  'brandonmychalsmith',
#  'brave',
#  'brazil',
#  'break',
#  'breakdown',
#  'breakthrough',
#  'breannayd',
#  'breath',
#  'breckinmey',
#  'brendangleeson',
#  'brendanscannel',
#  'brendasong',
#  'brentmorin',
#  'bret',
#  'bretharrison',
#  'brettgelman',
#  'brian',
#  'briangleeson',
#  'brianj',
#  'brianposehn',
#  'bride',
#  'bridg',
#  'bridget',
#  'bridgitmendl',
#  'brief',
#  'bright',
#  'brilliant',
#  'brinapalencia',
#  'bring',
#  'brink',
#  'brit',
#  'britain',
#  'british',
#  'brittlow',
#  'brittneykarbowski',
#  'brittrobertson',
#  'broadcast',
#  'broadway',
#  'broke',
#  'broken',
#  'broker',
#  'brook',
#  'brookedorsay',
#  'brothel',
#  'brother',
#  'brothers',
#  'brought',
#  'brown',
#  'brucecampbel',
#  'brutal',
#  'bryancranston',
#  'brycepapenbrook',
#  'brysonbaugu',
#  'bu',
#  'bubbl',
#  'buddi',
#  'budget',
#  'bugragülsoy',
#  'build',
#  'building',
#  'built',
#  'bulli',
#  'bunni',
#  'burakdeniz',
#  'burbag',
#  'burcubiricik',
#  'burcuözberk',
#  'bureau',
#  'buri',
#  'burn',
#  'burçinterzioglu',
#  'bush',
#  'busi',
#  'business',
#  'businessman',
#  'bustl',
#  'butcher',
#  'butler',
#  'buy',
#  'buyer',
#  'byrn',
#  'cafe',
#  'caglarertugrul',
#  'caitlincarmichael',
#  'caitlinglass',
#  'cal',
#  'california',
#  'caliph',
#  'came',
#  'camera',
#  'cameron',
#  'camila',
#  'camp',
#  'campaign',
#  'canada',
#  'canadian',
#  'canberra',
#  'cancer',
#  'candacecameronbur',
#  'candic',
#  'candid',
#  'cannabi',
#  'cannon',
#  'canyaman',
#  'cap',
#  'capabl',
#  'cape',
#  'caper',
#  'capit',
#  'captain',
#  'captiv',
#  'captur',
#  'car',
#  'care',
#  'career',
#  'carefre',
#  'caribahein',
#  'carlagugino',
#  'carllumbl',
#  'carlosalazraqui',
#  'carlospenavega',
#  'carlychaikin',
#  'carolina',
#  'carolinedhaverna',
#  'carrelllasso',
#  'carri',
#  'carrie',
#  'cars',
#  'carstenbjørnlund',
#  'cartel',
#  'carter',
#  'carterjenkin',
#  'case',
#  'cases',
#  'casey',
#  'caseydeidrick',
#  'caseysimpson',
#  'cash',
#  'casino',
#  'cassi',
#  'cast',
#  'castl',
#  'cat',
#  'catalina',
#  'catastroph',
#  'catch',
#  'cate',
#  'cater',
#  'catherin',
#  'catherinetab',
#  'cathol',
#  'cattl',
#  'caught',
#  'caus',
#  'ccg',
#  'cedricyarbrough',
#  'celebr',
#  'celia',
#  'cell',
#  'center',
#  'centr',
#  'central',
#  'centuri',
#  'century',
#  'ceo',
#  'cha',
#  'chadmichaelmurray',
#  'chaesoo',
#  'chagrin',
#  'chaihansen',
#  'chain',
#  'challeng',
#  'challenges',
#  'champion',
#  'championship',
#  'chanc',
#  'chance',
#  'chang',
#  'change',
#  'channel',
#  'channingtatum',
#  'chao',
#  'chapter',
#  'charact',
#  'character',
#  'characters',
#  'charg',
#  'charismat',
#  'charl',
#  'charli',
#  'charliehunnam',
#  'charliemurphi',
#  'charlieryan',
#  'charliesaxton',
#  'charlieschlatt',
#  'charlotteritchi',
#  'charm',
#  'charter',
#  'chase',
#  'chasers',
#  'chat',
#  'chateau',
#  'cheat',
#  'cheerlead',
#  'chef',
#  'chefs',
#  'chelsea',
#  'chelseakan',
#  'chemic',
#  'chemistri',
#  'cheramileigh',
#  'chicago',
#  'chicobenymon',
#  'chief',
#  'chihuahua',
#  'child',
#  'childhood',
#  'children',
#  'chill',
#  'chimcbrid',
#  'china',
#  'chines',
#  'chip',
#  'chiwasaitô',
#  'chloe',
#  'chloësevigni',
#  'choi',
#  'choic',
#  'choos',
#  'chosen',
#  'chrisdelia',
#  'chrisdiamantopoulo',
#  'chrisharrison',
#  'chrisjericho',
#  'chrisnoth',
#  'chrisodowd',
#  'chrisparnel',
#  'christ',
#  'christianslat',
#  'christinamos',
#  'christinaochoa',
#  'christinebottomley',
#  'christma',
#  'christopherbevin',
#  'christopheregan',
#  'christophergorham',
#  'christophermcculloch',
#  'christophermintz',
#  'christophersabat',
#  'chronicl',
#  'church',
#  'cia',
#  'ciarabravo',
#  'ciaránhind',
#  'circl',
#  'circumst',
#  'circumstances',
#  'citi',
#  'citizen',
#  'city',
#  'civil',
#  'civilian',
#  'civilization',
#  'claim',
#  'clair',
#  'clairefoy',
#  'clan',
#  'clandestin',
#  'clarkduk',
#  'clash',
#  'class',
#  'classic',
#  'classmat',
#  'classroom',
#  'claudia',
#  'clean',
#  'clear',
#  'clerk',
#  'clever',
#  'client',
#  'clients',
#  'cliff',
#  'climb',
#  'clinic',
#  'cliveowen',
#  'clock',
#  'clone',
#  'close',
#  'closer',
#  'closest',
#  'cloth',
#  'cloud',
#  'clown',
#  'club',
#  'clue',
#  'clémencepoési',
#  'coach',
#  'coal',
#  'coast',
#  'coastal',
#  'cobiesmuld',
#  'code',
#  'codi',
#  'coffe',
#  'cohen',
#  'coin',
#  'cold',
#  'colehaus',
#  'colesprous',
#  'colin',
#  'colinford',
#  'colinhank',
#  'colinmorgan',
#  'collaps',
#  'collar',
#  'colleagu',
#  'collect',
#  'colleg',
#  'collid',
#  'collide',
#  'colmmeaney',
#  'colombia',
#  'colombian',
#  'coloni',
#  'color',
#  'colorado',
#  'columnist',
#  'com',
#  'coma',
#  'combat',
#  'combin',
#  'come',
#  'comed',
#  'comedi',
#  'comedian',
#  'comedy',
#  'comfort',
#  'comic',
#  'coming',
#  'command',
#  'commentari',
#  'commerci',
#  'commission',
#  'commit',
#  'common',
#  'commun',
#  'communist',
#  'community',
#  'compani',
#  'companion',
#  'company',
#  'compel',
#  'compet',
#  'competit',
#  'competitor',
#  'complet',
#  'complex',
#  'complic',
#  'compos',
#  'compton',
#  'compuls',
#  'comput',
#  'conceal',
#  'concierg',
#  'condit',
#  'confeder',
#  'confess',
#  'confid',
#  'conflict',
#  'confront',
#  'confus',
#  'connect',
#  'conniebritton',
#  'conquer',
#  'conscienc',
#  'consequ',
#  'consequences',
#  'consid',
#  'consist',
#  'conspiraci',
#  'conspiracy',
#  'constancemari',
#  'constant',
#  'constantli',
#  'construct',
#  'consult',
#  'contact',
#  'contain',
#  'contemporari',
#  'content',
#  'contest',
#  'continu',
#  'contract',
#  'contrast',
#  'control',
#  'controversi',
#  'convict',
#  'convinc',
#  'cook',
#  'cool',
#  'cooper',
#  'cop',
#  'cope',
#  'copenhagen',
#  'cops',
#  'coreyburton',
#  'corner',
#  ...]

# %%
#using cosine similarity as a way to evaluate similarity and rank similar tv shows
similarity = cosine_similarity(vectors)

# %% [markdown]
# ## Recommending top 5 shows in similairty

# %%
def recommend(show):
    show_idx = df_final[df_final['Title'] == show].index[0]
    distances = similarity[show_idx]
    shows_list  = sorted(list(enumerate(distances)), reverse = True, key = lambda x:x[1])[1:6]
    for i in shows_list:
        print(df_final['Title'][i[0]])

# %%
recommend('Nature Cat')
# Out:
# Bravest Warriors
# Black Lagoon
# PJ Masks
# DuckTales
# Mar de plástico

# %%
import pickle
pickle.dump(df_final, open('shows.pkl', 'wb'))

# %%
pickle.dump(similarity, open('similarity.pkl', 'wb'))
